# %% [markdown]
# <a href="https://colab.research.google.com/github/AdamHuang0402/MLclass0423/blob/master/mongoDB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install dnspython
# Out:
# ...
#      |████████████████████████████████| 194kB 3.5MB/s
# ...

# %%
# !pip install pymongo[srv]

# %%
import pymongo
import dns

client = pymongo.MongoClient("mongodb://dbuser:1wsxzaq2@cluster0-shard-00-00-hrqx5.gcp.mongodb.net:27017,cluster0-shard-00-01-hrqx5.gcp.mongodb.net:27017,cluster0-shard-00-02-hrqx5.gcp.mongodb.net:27017/PTT?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.test

db
# Out:
# Database(MongoClient(host=['cluster0-shard-00-02-hrqx5.gcp.mongodb.net:27017', 'cluster0-shard-00-00-hrqx5.gcp.mongodb.net:27017', 'cluster0-shard-00-01-hrqx5.gcp.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, ssl=True, replicaset='Cluster0-shard-0', authsource='admin', retrywrites=True, w='majority'), 'test')

# %%
db = client.PTT
db
# Out:
# Database(MongoClient(host=['cluster0-shard-00-02-hrqx5.gcp.mongodb.net:27017', 'cluster0-shard-00-00-hrqx5.gcp.mongodb.net:27017', 'cluster0-shard-00-01-hrqx5.gcp.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, ssl=True, replicaset='Cluster0-shard-0', authsource='admin', retrywrites=True, w='majority'), 'PTT')

# %%
import pandas as pd
import datetime
import matplotlib.pyplot as pp
import pymongo
import dns

MONGO_DB='PTT'
MONGO_COLLETION='iphone'

def connect_mongo():  #連線資料庫
    global collection
    client = pymongo.MongoClient("mongodb://dbuser:1wsxzaq2@cluster0-shard-00-00-hrqx5.gcp.mongodb.net:27017,cluster0-shard-00-01-hrqx5.gcp.mongodb.net:27017,cluster0-shard-00-02-hrqx5.gcp.mongodb.net:27017/Cluster0?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin&retryWrites=true&w=majority")
    db = client[MONGO_DB]
    collection = db[MONGO_COLLETION]

connect_mongo()  #呼叫連線資料庫函式


# query = { 'Name': 'iphone_se_2' }
cursor = collection.find()  #依query查詢資料
stock =  pd.DataFrame(list(cursor))  #轉換成DataFrame

# %%
stock[5:]
# Out:
#                          _id  ...                                          apperance
# 5   5ee586fbf0f8ef0718470525  ...  [對於封閉系統真的用不習慣, 電池勒，是報多少, iPad3290iPhone2590好像是...
# 6   5ee58700f0f8ef0718470526  ...  [→Fezico:, 推tontontonni:, →andylin222:, 推taiwa...
# 7   5ee58702f0f8ef0718470527  ...  [ZF3基本上掛了，螢幕亂跳，修螢幕要2千多，5Z是最佳, 推分析xd, 選擇，但就是怕當趙...
# 8   5ee58703f0f8ef0718470528  ...  [猜會有二代Airpods, 一年要辦幾次佈道大會啊？, airpods哪時改typec, ...
# 9   5ee5870bf0f8ef0718470529  ...  [ZF3基本上掛了，螢幕亂跳，修螢幕要2千多，5Z是最佳, 推分析xd, 選擇，但就是怕當趙...
# 10  5ee5870cf0f8ef071847052a  ...  [ZF3基本上掛了，螢幕亂跳，修螢幕要2千多，5Z是最佳, 推分析xd, 選擇，但就是怕當趙...
# 11  5ee58711f0f8ef071847052b  ...  [ZF3基本上掛了，螢幕亂跳，修螢幕要2千多，5Z是最佳, 推分析xd, 選擇，但就是怕當趙...
# 12  5ee5871cf0f8ef071847052c  ...  [4a只贏拍照跟續航吧, 我看兩者的相機參數差不多說, 不打遊戲日常使用會差到哪裡去但是se...
# 13  5ee5871df0f8ef071847052d  ...  [不愧是蘋果螢幕品質真的好到沒話說, 中國二線廠牌很多都用維信諾，一線廠牌華為用的京, 東方...
# 14  5ee5871ef0f8ef071847052e  ...  [一台四五萬的手機感光元件還用那麼爛我也是服了, 一到暗處就偏黃, 只需要單鏡頭的....,...
# ...

# %%
test =  pd.DataFrame({"Name":stock["Name"][0]})
test
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-2502ff757a03> in <module>()
# ----> 1 test =  pd.DataFrame({"Name":stock["Name"][0]})
#       2 test
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ...

# %%
import json

with open("/content/drive/My Drive/AI_class_project/data_PTT/ptt_google.json", "r", encoding="utf-8") as file_object:
  f = json.load(file_object)
f
# Out:
# [{'Name': 'pixel',
#   'apperance': ['P30proI',
#    'II',
#    'Plus一系列囉',
#    'AmIajoketoyou?',
#    'GMS認證要求核心零件(處理器',
#    '基頻',
#    '像素等)不能更動.',
#    '改個顏色重新上市還好啦',
#    '不是說hms很棒棒嗎某人怎不7pupu一下',
#    '華為賣點：我們有GMS！',
#    '你放心鴻蒙不會停止的',
#    '就上市一年前的旗艦機啊！其實有點爛！',
#    '那只要P40、P50、P60...都取叫做P30特別版/升級版',
#    '，事情不就都解決了？',
#    '韭菜用哄蒙外國人用谷歌老闆自己用蘋果',
#    '華為也要P30+++++++了嗎？',
#    '艾希',
#    'P30ver1.0ver2.0ver3.0.....',
#    '還不趕快出征',
#    'P30pro麒麟990版+IMX700',
#    '洪蒙那麼好用幹嘛放棄',
#    '之前一堆不懂商業模式的中國人在吹噓鴻蒙要取代GMS',
#    '去年在吹鴻蒙的小粉紅去哪了',
#    'P30forever~~',
#    '愛國小粉紅不出征一下嗎',
#    'gms真香',
#    '想買',
#    '呵呵呵',
#    '說好的鴻蒙?',
#    '還可以換10年顏色嗎V.2030為了GMS',
#    '想買',
#    '五毛不來出征一下這個中美貿易戰的叛徒?',
#    '都只能用980可憐吶',
#    '早上剛舒服完過沒多久就有禁令延長的新聞出現XD',
#    '花25000買一台去年的旗艦手機，S10還只要1萬多',
#    '日光燈的閃爍頻率？',
#    '快門速度調一下應該就可以解決?',
#    '日光燈的問題',
#    '你在全聯做狹縫實驗嗎',
#    'google原廠相機app沒地方可以調QQ',
#    '請支援收銀',
#    '福力熊熊福麗',
#    '那是相機原理，不是Bug',
#    '請支援收銀',
#    '我覺得不是日光燈頻率問題',
# ...

# %%
import pandas as pd
import datetime
import matplotlib.pyplot as pp
import pymongo
import dns

df =  pd.DataFrame(list(f))  #轉換成DataFrame
df
# Out:
#         Name  ...                                          apperance
# 0      pixel  ...  [P30proI, II, Plus一系列囉, AmIajoketoyou?, GMS認證要...
# 1    pixelxl  ...  [日光燈的閃爍頻率？, 快門速度調一下應該就可以解決?, 日光燈的問題, 你在全聯做狹縫實驗...
# 2     pixel2  ...  [天才, 原來文組誤國是真的, 有時間搞那些不如檢討自已賺錢能力為何買不起蘋果, 笑死真的是...
# 3   pixel2xl  ...  [這種產品適合拿來轉賣互通有無促進經濟, Google有沒有台灣的員工在看這個版啊，這種服務...
# 4     pixel3  ...  [P30proI, II, Plus一系列囉, AmIajoketoyou?, GMS認證要...
# 5   pixel3xl  ...  [不是老早就都沒貨了, 33xl的相機真的是無敵到一個不行, pixel3除了續行其他很好,...
# 6    pixel3a  ...  [日光燈的閃爍頻率？, 快門速度調一下應該就可以解決?, 日光燈的問題, 你在全聯做狹縫實驗...
# 7  pixel3axl  ...  [Google家的電池484很貴啊容量怎麼都這麼小, 七月中出不如不要出, 邊框堪比唉鳳LC...
# 8     pixel4  ...  [P30proI, II, Plus一系列囉, AmIajoketoyou?, GMS認證要...
# 9   pixel4xl  ...  [日光燈的閃爍頻率？, 快門速度調一下應該就可以解決?, 日光燈的問題, 你在全聯做狹縫實驗...
#
# [10 rows x 5 columns]

# %%
import pandas as pd
import datetime
import matplotlib.pyplot as pp
import pymongo
import dns

MONGO_DB='PTT'
MONGO_COLLETION='google'

def connect_mongo():  #連線資料庫
    global collection
    client = pymongo.MongoClient("mongodb://dbuser:1wsxzaq2@cluster0-shard-00-00-hrqx5.gcp.mongodb.net:27017,cluster0-shard-00-01-hrqx5.gcp.mongodb.net:27017,cluster0-shard-00-02-hrqx5.gcp.mongodb.net:27017/<dbname>?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin&retryWrites=true&w=majority")
    db = client[MONGO_DB]
    collection = db[MONGO_COLLETION]

connect_mongo()  #呼叫連線資料庫函式

# data = []
for i in range(0,len(df)):
  a_type = dict({"Name":df["Name"][i], 
                 "apperance":df["apperance"][i]})
  # data.append(a_type)
  result = collection.insert_one(a_type)


result

# %%
df["performance"][0]
# Out:
# ['P30proI',
#  'II',
#  'Plus一系列囉',
#  'AmIajoketoyou?',
#  'GMS認證要求核心零件(處理器',
#  '基頻',
#  '像素等)不能更動.',
#  '改個顏色重新上市還好啦',
#  '不是說hms很棒棒嗎某人怎不7pupu一下',
#  '華為賣點：我們有GMS！',
#  '你放心鴻蒙不會停止的',
#  '就上市一年前的旗艦機啊！其實有點爛！',
#  '那只要P40、P50、P60...都取叫做P30特別版/升級版',
#  '，事情不就都解決了？',
#  '韭菜用哄蒙外國人用谷歌老闆自己用蘋果',
#  '華為也要P30+++++++了嗎？',
#  '艾希',
#  'P30ver1.0ver2.0ver3.0.....',
#  '還不趕快出征',
#  'P30pro麒麟990版+IMX700',
#  '洪蒙那麼好用幹嘛放棄',
#  '之前一堆不懂商業模式的中國人在吹噓鴻蒙要取代GMS',
#  '去年在吹鴻蒙的小粉紅去哪了',
#  'P30forever~~',
#  '愛國小粉紅不出征一下嗎',
#  'gms真香',
#  '想買',
#  '呵呵呵',
#  '說好的鴻蒙?',
#  '還可以換10年顏色嗎V.2030為了GMS',
#  '想買',
#  '五毛不來出征一下這個中美貿易戰的叛徒?',
#  '都只能用980可憐吶',
#  '早上剛舒服完過沒多久就有禁令延長的新聞出現XD',
#  '花25000買一台去年的旗艦手機，S10還只要1萬多',
#  '電子垃圾處理成本過高',
#  '不小心賣到成本價',
#  '傳說中的假一賠3？',
#  '別人降300美，我們降3k3k>0.3k好棒棒',
#  '如果在台灣收到寄錯的，留下來用會怎樣嗎？',
#  '告你侵占',
#  '戶頭莫名多了1億趕快領出來花光??',
#  '處理退貨的成本更貴',
#  '買1送10台灣不知道有沒有',
#  '谷歌總是讓人驚喜',
#  '亞馬遜也幹過這種事',
#  '很好奇在台灣真的會被告侵占嗎？不是賣方自己的疏失',
#  '要自己吞嗎',
#  '之前在露天拍賣也遇過買一組變兩組',
#  '告侵占要舉證阿，所以收到記得低調',
# ...

# %%
import pandas as pd
import datetime
import matplotlib.pyplot as pp
import pymongo
import dns

MONGO_DB='PTT'
MONGO_COLLETION='google'

def connect_mongo():  #連線資料庫
    global collection
    client = pymongo.MongoClient("mongodb://dbuser:1wsxzaq2@cluster0-shard-00-00-hrqx5.gcp.mongodb.net:27017,cluster0-shard-00-01-hrqx5.gcp.mongodb.net:27017,cluster0-shard-00-02-hrqx5.gcp.mongodb.net:27017/Cluster0?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin&retryWrites=true&w=majority")
    db = client[MONGO_DB]
    collection = db[MONGO_COLLETION]

connect_mongo()  #呼叫連線資料庫函式


# query = { 'Name': 'iphone_se_2' }
cursor = collection.find()  #依query查詢資料
stock =  pd.DataFrame(list(cursor))  #轉換成DataFrame

# %%
stock
# Out:
#                         _id  ...                                          apperance
# 0  5ee5f0b5552ed65663c53c2c  ...  [P30proI, II, Plus一系列囉, AmIajoketoyou?, GMS認證要...
# 1  5ee5f0f2552ed65663c53c2d  ...  [日光燈的閃爍頻率？, 快門速度調一下應該就可以解決?, 日光燈的問題, 你在全聯做狹縫實驗...
# 2  5ee5f121552ed65663c53c2e  ...  [天才, 原來文組誤國是真的, 有時間搞那些不如檢討自已賺錢能力為何買不起蘋果, 笑死真的是...
# 3  5ee5f13d552ed65663c53c2f  ...  [這種產品適合拿來轉賣互通有無促進經濟, Google有沒有台灣的員工在看這個版啊，這種服務...
# 4  5ee5f148552ed65663c53c30  ...  [P30proI, II, Plus一系列囉, AmIajoketoyou?, GMS認證要...
# 5  5ee5f170552ed65663c53c31  ...  [不是老早就都沒貨了, 33xl的相機真的是無敵到一個不行, pixel3除了續行其他很好,...
# 6  5ee5f180552ed65663c53c32  ...  [日光燈的閃爍頻率？, 快門速度調一下應該就可以解決?, 日光燈的問題, 你在全聯做狹縫實驗...
# 7  5ee5f18d552ed65663c53c33  ...  [Google家的電池484很貴啊容量怎麼都這麼小, 七月中出不如不要出, 邊框堪比唉鳳LC...
# 8  5ee5f191552ed65663c53c34  ...  [P30proI, II, Plus一系列囉, AmIajoketoyou?, GMS認證要...
# 9  5ee5f1ae552ed65663c53c35  ...  [日光燈的閃爍頻率？, 快門速度調一下應該就可以解決?, 日光燈的問題, 你在全聯做狹縫實驗...
#
# [10 rows x 3 columns]
